# %% [markdown]
# # CSV Onboarding
#
# **Prerequisite**:
#
# - Installed Neat, see [Installation](../../gettingstarted/installation.html)
# - Launched a notebook environment.
# - Familiar with the `NeatSession` object, see [introduction](../introduction/introduction.html)
# - Access to `NeatEngine`
#
#
#
# In this tutorial, we will load data from a `csv`, infer a data model from the data and push the model with data to CDF.

# %% [markdown]
# ## Reading Metadata

# %% [markdown]
# We will start by instansiating a `NeatSession` and read the data from an URL.

# %%
from cognite.neat import NeatSession, get_cognite_client

# %%
neat = NeatSession(get_cognite_client(".env"))
# Out:
# Found .env file in repository root. Loaded variables from .env file.
# Neat Engine 2.0.3 loaded.

# %% [markdown]
# A snippet of the data we are reading are shown below
#
#
# ```csv
# ELC_STATUS_ID,RES_ID,SOURCE_DB,SOURCE_TABLE,WMT_AREA_ID,WMT_CATEGORY_ID,WMT_CONTRACTOR_ID,WMT_FUNC_CODE_ID,WMT_LOCATION_ID,WMT_PO_ID,WMT_SAFETYCRITICALELEMENT_ID,WMT_SYSTEM_ID,WMT_TAG_CREATED_DATE,WMT_TAG_CRITICALLINE,WMT_TAG_DESC,WMT_TAG_GLOBALID,WMT_TAG_HISTORYREQUIRED,WMT_TAG_ID,WMT_TAG_ID_ANCESTOR,WMT_TAG_ISACTIVE,WMT_TAG_ISOWNEDBYPROJECT,WMT_TAG_LOOP,WMT_TAG_MAINID,WMT_TAG_NAME,WMT_TAG_UPDATED_BY,WMT_TAG_UPDATED_DATE,WMT_TAG_STATUSCHGDATE,WMT_TAG_COMMENT,WMT_TAG_SUFFIX,WMT_SYSTEM_ACTIVE,WMT_SYSTEM_CODE,WMT_SYSTEM_DESC,WMT_SYSTEM_NAME,WMT_LOCATION_ACTIVE,WMT_LOCATION_CODE,WMT_LOCATION_EXTENDACTIVEWOP,WMT_LOCATION_EXTERNALOWNERSHIP,WMT_LOCATION_MAITIS,WMT_LOCATION_NAME,WMT_LOCATION_NOCOPIESDEFAULTIC,WMT_LOCATION_NOCOPIESWOPERMIT,WMT_LOCATION_OPERATIONHOURS,WMT_LOCATION_PROGVALUE,WMT_LOCATION_SIMULATETIMEFRAME,WMT_LOCATION_SJAMAXNOOFTASKS,WMT_LOCATION_USEPLOTALTITUDE,WMT_LOCATION_WORKSTART,latestUpdateTimeSource
# 1211,525283,workmate,wmate_dba.wmt_tag,1600,1116,1686,4564,1004,8309,1060,4440,26/06/2009 15:36,N,VRD - PH 1STSTGGEAR THRUST BRG OUT,1000000000681024,Y,346434,345637,1,0,96116,681760,23-TE-96116-04,8137,11/07/2014 09:25,,,,,,,,,,,,,,,,,,,,,,
# 1211,532924,workmate,wmate_dba.wmt_tag,1600,1116,1686,4564,1004,8309,1060,4440,26/06/2009 15:36,N,VRD - PH 1STSTG COMP SEAL GAS HTR,1000000000682252,Y,346452,346633,1,0,96148,681760,23-TE-96148,8137,11/07/2014 09:25,,,,,,,,,,,,,,,,,,,,,,
# 1211,446683,workmate,wmate_dba.wmt_tag,1600,1116,1686,4627,1004,8309,1060,4440,26/06/2009 15:36,N,VRD - PH 1STSTGGEAR 1 JOURNBRG DE,1000000000715794,Y,346995,346935,1,0,96117,681760,23-YT-96117-01,9802,09/12/2013 12:53,,,,,,,,,,,,,,,,,,,,,,
# 1211,,workmate,wmate_dba.wmt_tag,1600,1152,1686,11275,1004,,,4440,13/12/2012 14:13,N,SOFT TAG VRD - PH 1STSTG PRIM SEAL LEAK DE,1000000000250739,Y,682956,345868,1,0,,681760,23-FI-96151,1001,09/10/2015 11:56,06/10/2014 07:45,,,,,,,,,,,,,,,,,,,,,
# ```

# %% [markdown]
# To read a `csv`, we need to tell neat what typ of data is in the source, as well as which column is the identifier.
#
# We know that this data contains assets and that the column `WMT_TAG_GLOBALID` is the unique identifier of these assets.

# %%
url = "https://apps-cdn.cogniteapp.com/toolkit/publicdata/assets.Table.csv"

# %%
neat.read.csv(url, type="Asset", primary_key="WMT_TAG_GLOBALID")

# %%
neat
# Out:
# <H2>Instances</H2> <br /><strong>Overview</strong>:<ul><li>1 types</strong></li><li>1103 instances</strong></li></ul><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Occurrence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Asset</td>
#       <td>1103</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><strong>Provenance</strong>:<ul><li>Initialize graph store as Memory</li><li>Extracted triples to graph store using CSVExtractor</li></ul>

# %% [markdown]
# Studying the output above, we see that we succesfully read 1103 assets into the `NeatSession`.

# %% [markdown]
# ## Infer Data Model

# %% [markdown]
# We can infer a data model from data in the `NeatSession` by calling `.infer()`.

# %%
neat.infer()
# Out:
# []

# %%
neat
# Out:
# <H2>Unverified Data Model</H2><br /><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>type</th>
#       <td>Logical Data Model</td>
#     </tr>
#     <tr>
#       <th>intended for</th>
#       <td>Information Architect</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>Inferred Model</td>
#     </tr>
#     <tr>
#       <th>external_id</th>
#       <td>NeatInferredDataModel</td>
#     </tr>
#     <tr>
#       <th>space</th>
#       <td>neat_space</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>v1</td>
#     </tr>
#     <tr>
#       <th>classes</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>properties</th>
#       <td>29</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><H2>Instances</H2> <br /><strong>Overview</strong>:<ul><li>1 types</strong></li><li>1103 instances</strong></li></ul><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Occurrence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Asset</td>
#       <td>1103</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><strong>Provenance</strong>:<ul><li>Initialize graph store as Memory</li><li>Extracted triples to graph store using CSVExtractor</li></ul>

# %% [markdown]
# This gives us an unverified data model, which we can then verify.

# %% [markdown]
# ## Verify Data Model

# %%
neat.verify()
# Out:
# []

# %%
neat.inspect.properties
# Out:
#                                                neatId            class_  \
# 0   http://purl.org/cognite/neat/neatId_d8361e5d_6...  neat_space:Asset
# 1   http://purl.org/cognite/neat/neatId_eeadc1d3_0...  neat_space:Asset
# 2   http://purl.org/cognite/neat/neatId_09ff7299_9...  neat_space:Asset
# 3   http://purl.org/cognite/neat/neatId_1cf678ed_0...  neat_space:Asset
# 4   http://purl.org/cognite/neat/neatId_aa0d7c62_5...  neat_space:Asset
# 5   http://purl.org/cognite/neat/neatId_7e3d5353_2...  neat_space:Asset
# 6   http://purl.org/cognite/neat/neatId_400299ec_e...  neat_space:Asset
# 7   http://purl.org/cognite/neat/neatId_41883b12_5...  neat_space:Asset
# 8   http://purl.org/cognite/neat/neatId_b35f6e65_4...  neat_space:Asset
# 9   http://purl.org/cognite/neat/neatId_1c74cead_e...  neat_space:Asset
# 10  http://purl.org/cognite/neat/neatId_7a772023_b...  neat_space:Asset
# 11  http://purl.org/cognite/neat/neatId_ddff5ea9_7...  neat_space:Asset
# 12  http://purl.org/cognite/neat/neatId_903922fe_9...  neat_space:Asset
# 13  http://purl.org/cognite/neat/neatId_e111cd9f_4...  neat_space:Asset
# 14  http://purl.org/cognite/neat/neatId_b2a0c67c_6...  neat_space:Asset
# 15  http://purl.org/cognite/neat/neatId_77ea03a1_4...  neat_space:Asset
# 16  http://purl.org/cognite/neat/neatId_125280ef_9...  neat_space:Asset
# 17  http://purl.org/cognite/neat/neatId_985216e3_3...  neat_space:Asset
# 18  http://purl.org/cognite/neat/neatId_28073c22_f...  neat_space:Asset
# 19  http://purl.org/cognite/neat/neatId_56a1019f_2...  neat_space:Asset
# 20  http://purl.org/cognite/neat/neatId_751bbb24_1...  neat_space:Asset
# 21  http://purl.org/cognite/neat/neatId_5b64af9c_3...  neat_space:Asset
# 22  http://purl.org/cognite/neat/neatId_8431ac6e_1...  neat_space:Asset
# 23  http://purl.org/cognite/neat/neatId_1492bb6f_7...  neat_space:Asset
# 24  http://purl.org/cognite/neat/neatId_d8367aac_9...  neat_space:Asset
# 25  http://purl.org/cognite/neat/neatId_5ed79f3d_1...  neat_space:Asset
# 26  http://purl.org/cognite/neat/neatId_7408f270_1...  neat_space:Asset
# 27  http://purl.org/cognite/neat/neatId_59441498_b...  neat_space:Asset
# 28  http://purl.org/cognite/neat/neatId_c827b3db_3...  neat_space:Asset
#
#                        property_ value_type  max_count  \
# 0                 WMT_TAG_MAINID       long          1
# 1                WMT_CATEGORY_ID       long          1
# 2                      SOURCE_DB     string          1
# 3            WMT_TAG_ID_ANCESTOR       long          1
# 4        WMT_TAG_HISTORYREQUIRED     string          1
# 5                      WMT_PO_ID       long          1
# 6                   WMT_TAG_LOOP     string          1
# 7                         RES_ID       long          1
# 8                    WMT_AREA_ID       long          1
# 9           WMT_TAG_UPDATED_DATE     string          1
# 10                  WMT_TAG_DESC     string          1
# 11              WMT_TAG_ISACTIVE       long          1
# 12                 ELC_STATUS_ID       long          1
# 13          WMT_TAG_CRITICALLINE     string          1
# 14                 WMT_SYSTEM_ID       long          1
# 15               WMT_TAG_COMMENT     string          1
# 16          WMT_TAG_CREATED_DATE   dateTime          1
# 17         WMT_TAG_STATUSCHGDATE     string          1
# 18  WMT_SAFETYCRITICALELEMENT_ID       long          1
# 19            WMT_TAG_UPDATED_BY       long          1
# 20      WMT_TAG_ISOWNEDBYPROJECT       long          1
# 21                    WMT_TAG_ID       long          1
# 22             WMT_CONTRACTOR_ID       long          1
# 23              WMT_TAG_GLOBALID       long          1
# 24              WMT_FUNC_CODE_ID       long          1
# 25                  SOURCE_TABLE     string          1
# 26               WMT_LOCATION_ID       long          1
# 27                  WMT_TAG_NAME     string          1
# 28                WMT_TAG_SUFFIX     string          1
#
#                                        transformation
# 0             prefix_1:Asset(prefix_1:WMT_TAG_MAINID)
# 1            prefix_1:Asset(prefix_1:WMT_CATEGORY_ID)
# 2                  prefix_1:Asset(prefix_1:SOURCE_DB)
# 3        prefix_1:Asset(prefix_1:WMT_TAG_ID_ANCESTOR)
# 4    prefix_1:Asset(prefix_1:WMT_TAG_HISTORYREQUIRED)
# 5                  prefix_1:Asset(prefix_1:WMT_PO_ID)
# 6               prefix_1:Asset(prefix_1:WMT_TAG_LOOP)
# 7                     prefix_1:Asset(prefix_1:RES_ID)
# 8                prefix_1:Asset(prefix_1:WMT_AREA_ID)
# 9       prefix_1:Asset(prefix_1:WMT_TAG_UPDATED_DATE)
# 10              prefix_1:Asset(prefix_1:WMT_TAG_DESC)
# 11          prefix_1:Asset(prefix_1:WMT_TAG_ISACTIVE)
# 12             prefix_1:Asset(prefix_1:ELC_STATUS_ID)
# 13      prefix_1:Asset(prefix_1:WMT_TAG_CRITICALLINE)
# 14             prefix_1:Asset(prefix_1:WMT_SYSTEM_ID)
# 15           prefix_1:Asset(prefix_1:WMT_TAG_COMMENT)
# 16      prefix_1:Asset(prefix_1:WMT_TAG_CREATED_DATE)
# 17     prefix_1:Asset(prefix_1:WMT_TAG_STATUSCHGDATE)
# 18  prefix_1:Asset(prefix_1:WMT_SAFETYCRITICALELEM...
# 19        prefix_1:Asset(prefix_1:WMT_TAG_UPDATED_BY)
# 20  prefix_1:Asset(prefix_1:WMT_TAG_ISOWNEDBYPROJECT)
# 21                prefix_1:Asset(prefix_1:WMT_TAG_ID)
# 22         prefix_1:Asset(prefix_1:WMT_CONTRACTOR_ID)
# 23          prefix_1:Asset(prefix_1:WMT_TAG_GLOBALID)
# 24          prefix_1:Asset(prefix_1:WMT_FUNC_CODE_ID)
# 25              prefix_1:Asset(prefix_1:SOURCE_TABLE)
# 26           prefix_1:Asset(prefix_1:WMT_LOCATION_ID)
# 27              prefix_1:Asset(prefix_1:WMT_TAG_NAME)
# 28            prefix_1:Asset(prefix_1:WMT_TAG_SUFFIX)

# %% [markdown]
# After inspecting the properties, we notice that we have a `Logical Data Model`. This cannot be written to CDF. To do that we will convert it to the `dms` format
# which is what CDF expects for data models.

# %% [markdown]
# ## Convert Data Model

# %%
neat.convert("dms")
# Out:
# Rules converted to dms
# []

# %%
neat.inspect.properties
# Out:
#                                                neatId  \
# 0   http://purl.org/cognite/neat/neatId_5faadcc1_6...
# 1   http://purl.org/cognite/neat/neatId_fa3c372e_8...
# 2   http://purl.org/cognite/neat/neatId_377ee5b8_a...
# 3   http://purl.org/cognite/neat/neatId_079ee68a_5...
# 4   http://purl.org/cognite/neat/neatId_1699d866_0...
# 5   http://purl.org/cognite/neat/neatId_099ef580_1...
# 6   http://purl.org/cognite/neat/neatId_50ea8557_e...
# 7   http://purl.org/cognite/neat/neatId_4c346538_f...
# 8   http://purl.org/cognite/neat/neatId_91240831_d...
# 9   http://purl.org/cognite/neat/neatId_4300fb48_4...
# 10  http://purl.org/cognite/neat/neatId_68e32492_1...
# 11  http://purl.org/cognite/neat/neatId_1f0a862f_3...
# 12  http://purl.org/cognite/neat/neatId_c98da295_7...
# 13  http://purl.org/cognite/neat/neatId_bf4a96b9_3...
# 14  http://purl.org/cognite/neat/neatId_8660dd4f_4...
# 15  http://purl.org/cognite/neat/neatId_f447092a_1...
# 16  http://purl.org/cognite/neat/neatId_d7a8763f_b...
# 17  http://purl.org/cognite/neat/neatId_84ef3395_4...
# 18  http://purl.org/cognite/neat/neatId_99ebe6d5_4...
# 19  http://purl.org/cognite/neat/neatId_756c74e2_8...
# 20  http://purl.org/cognite/neat/neatId_d6ab8f72_1...
# 21  http://purl.org/cognite/neat/neatId_d2ad894d_4...
# 22  http://purl.org/cognite/neat/neatId_84e3b5d3_6...
# 23  http://purl.org/cognite/neat/neatId_13ba3602_b...
# 24  http://purl.org/cognite/neat/neatId_8fea286f_6...
# 25  http://purl.org/cognite/neat/neatId_557c12e2_1...
# 26  http://purl.org/cognite/neat/neatId_87524b2f_a...
# 27  http://purl.org/cognite/neat/neatId_6decc546_1...
# 28  http://purl.org/cognite/neat/neatId_e90a728b_0...
#
#                             view                 view_property value_type  \
# 0   neat_space:Asset(version=v1)                WMT_TAG_MAINID      int64
# 1   neat_space:Asset(version=v1)               WMT_CATEGORY_ID      int64
# 2   neat_space:Asset(version=v1)                     SOURCE_DB       text
# 3   neat_space:Asset(version=v1)           WMT_TAG_ID_ANCESTOR      int64
# 4   neat_space:Asset(version=v1)       WMT_TAG_HISTORYREQUIRED       text
# 5   neat_space:Asset(version=v1)                     WMT_PO_ID      int64
# 6   neat_space:Asset(version=v1)                  WMT_TAG_LOOP       text
# 7   neat_space:Asset(version=v1)                        RES_ID      int64
# 8   neat_space:Asset(version=v1)                   WMT_AREA_ID      int64
# 9   neat_space:Asset(version=v1)          WMT_TAG_UPDATED_DATE       text
# 10  neat_space:Asset(version=v1)                  WMT_TAG_DESC       text
# 11  neat_space:Asset(version=v1)              WMT_TAG_ISACTIVE      int64
# 12  neat_space:Asset(version=v1)                 ELC_STATUS_ID      int64
# 13  neat_space:Asset(version=v1)          WMT_TAG_CRITICALLINE       text
# 14  neat_space:Asset(version=v1)                 WMT_SYSTEM_ID      int64
# 15  neat_space:Asset(version=v1)               WMT_TAG_COMMENT       text
# 16  neat_space:Asset(version=v1)          WMT_TAG_CREATED_DATE  timestamp
# 17  neat_space:Asset(version=v1)         WMT_TAG_STATUSCHGDATE       text
# 18  neat_space:Asset(version=v1)  WMT_SAFETYCRITICALELEMENT_ID      int64
# 19  neat_space:Asset(version=v1)            WMT_TAG_UPDATED_BY      int64
# 20  neat_space:Asset(version=v1)      WMT_TAG_ISOWNEDBYPROJECT      int64
# 21  neat_space:Asset(version=v1)                    WMT_TAG_ID      int64
# 22  neat_space:Asset(version=v1)             WMT_CONTRACTOR_ID      int64
# 23  neat_space:Asset(version=v1)              WMT_TAG_GLOBALID      int64
# 24  neat_space:Asset(version=v1)              WMT_FUNC_CODE_ID      int64
# 25  neat_space:Asset(version=v1)                  SOURCE_TABLE       text
# 26  neat_space:Asset(version=v1)               WMT_LOCATION_ID      int64
# 27  neat_space:Asset(version=v1)                  WMT_TAG_NAME       text
# 28  neat_space:Asset(version=v1)                WMT_TAG_SUFFIX       text
#
#     nullable  is_list         container            container_property  \
# 0       True    False  neat_space:Asset                WMT_TAG_MAINID
# 1       True    False  neat_space:Asset               WMT_CATEGORY_ID
# 2       True    False  neat_space:Asset                     SOURCE_DB
# 3       True    False  neat_space:Asset           WMT_TAG_ID_ANCESTOR
# 4       True    False  neat_space:Asset       WMT_TAG_HISTORYREQUIRED
# 5       True    False  neat_space:Asset                     WMT_PO_ID
# 6       True    False  neat_space:Asset                  WMT_TAG_LOOP
# 7       True    False  neat_space:Asset                        RES_ID
# 8       True    False  neat_space:Asset                   WMT_AREA_ID
# 9       True    False  neat_space:Asset          WMT_TAG_UPDATED_DATE
# 10      True    False  neat_space:Asset                  WMT_TAG_DESC
# 11      True    False  neat_space:Asset              WMT_TAG_ISACTIVE
# 12      True    False  neat_space:Asset                 ELC_STATUS_ID
# 13      True    False  neat_space:Asset          WMT_TAG_CRITICALLINE
# 14      True    False  neat_space:Asset                 WMT_SYSTEM_ID
# 15      True    False  neat_space:Asset               WMT_TAG_COMMENT
# 16      True    False  neat_space:Asset          WMT_TAG_CREATED_DATE
# 17      True    False  neat_space:Asset         WMT_TAG_STATUSCHGDATE
# 18      True    False  neat_space:Asset  WMT_SAFETYCRITICALELEMENT_ID
# 19      True    False  neat_space:Asset            WMT_TAG_UPDATED_BY
# 20      True    False  neat_space:Asset      WMT_TAG_ISOWNEDBYPROJECT
# 21      True    False  neat_space:Asset                    WMT_TAG_ID
# 22      True    False  neat_space:Asset             WMT_CONTRACTOR_ID
# 23      True    False  neat_space:Asset              WMT_TAG_GLOBALID
# 24      True    False  neat_space:Asset              WMT_FUNC_CODE_ID
# 25      True    False  neat_space:Asset                  SOURCE_TABLE
# 26      True    False  neat_space:Asset               WMT_LOCATION_ID
# 27      True    False  neat_space:Asset                  WMT_TAG_NAME
# 28      True    False  neat_space:Asset                WMT_TAG_SUFFIX
#
#                                               logical
# 0   http://purl.org/cognite/neat/neatId_d8361e5d_6...
# 1   http://purl.org/cognite/neat/neatId_eeadc1d3_0...
# 2   http://purl.org/cognite/neat/neatId_09ff7299_9...
# 3   http://purl.org/cognite/neat/neatId_1cf678ed_0...
# 4   http://purl.org/cognite/neat/neatId_aa0d7c62_5...
# 5   http://purl.org/cognite/neat/neatId_7e3d5353_2...
# 6   http://purl.org/cognite/neat/neatId_400299ec_e...
# 7   http://purl.org/cognite/neat/neatId_41883b12_5...
# 8   http://purl.org/cognite/neat/neatId_b35f6e65_4...
# 9   http://purl.org/cognite/neat/neatId_1c74cead_e...
# 10  http://purl.org/cognite/neat/neatId_7a772023_b...
# 11  http://purl.org/cognite/neat/neatId_ddff5ea9_7...
# 12  http://purl.org/cognite/neat/neatId_903922fe_9...
# 13  http://purl.org/cognite/neat/neatId_e111cd9f_4...
# 14  http://purl.org/cognite/neat/neatId_b2a0c67c_6...
# 15  http://purl.org/cognite/neat/neatId_77ea03a1_4...
# 16  http://purl.org/cognite/neat/neatId_125280ef_9...
# 17  http://purl.org/cognite/neat/neatId_985216e3_3...
# 18  http://purl.org/cognite/neat/neatId_28073c22_f...
# 19  http://purl.org/cognite/neat/neatId_56a1019f_2...
# 20  http://purl.org/cognite/neat/neatId_751bbb24_1...
# 21  http://purl.org/cognite/neat/neatId_5b64af9c_3...
# 22  http://purl.org/cognite/neat/neatId_8431ac6e_1...
# 23  http://purl.org/cognite/neat/neatId_1492bb6f_7...
# 24  http://purl.org/cognite/neat/neatId_d8367aac_9...
# 25  http://purl.org/cognite/neat/neatId_5ed79f3d_1...
# 26  http://purl.org/cognite/neat/neatId_7408f270_1...
# 27  http://purl.org/cognite/neat/neatId_59441498_b...
# 28  http://purl.org/cognite/neat/neatId_c827b3db_3...

# %% [markdown]
# Now we see that we have information about how the data model is implemented.
#
# We can further show the steps we have been taking so far, called the provenance of the data model.

# %%
neat.show.data_model.provenance()
# Out:
# data_model_provenance_2c5f64cf.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="data_model_provenance_2c5f64cf.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# We notice that we get the default space and model identifier, so we set it to be unique.

# %% [markdown]
# ## Publish Data Model

# %%
neat.set.data_model_id(("sp_doctrino", "DoctrinoAssetModel", "v1"))
# Out:
# []

# %% [markdown]
# Now we are ready to publish this to CDF.

# %%
neat.to.cdf.data_model()
# Out:
# ---------------------------------------------------------------------------
# NeatValueError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 neat.to.cdf.data_model()
#
# File ~\Projects\internal\neat\cognite\neat\_session\exceptions.py:28, in _session_method_wrapper.<locals>.wrapper(*args, **kwargs)
#      26 _COLLECTOR.track_session_command(f"{cls_name}.{func.__name__}", *args, **kwargs)
#      27 try:
# ---> 28     return func(*args, **kwargs)
#      29 except NeatSessionError as e:
#      30     action = _get_action()
#
# File ~\Projects\internal\neat\cognite\neat\_session\_to.py:197, in CDFToAPI.data_model(self, existing, dry_run, drop_data, components)
#     194 if not self._client:
#     195     raise NeatSessionError("No client provided!")
# --> 197 result = self._state.rule_store.export_to_cdf(exporter, self._client, dry_run)
#     198 print("You can inspect the details with the .inspect.outcome.data_model(...) method.")
#     199 return result
#
# File ~\Projects\internal\neat\cognite\neat\_store\_rules_store.py:72, in NeatRulesStore.export_to_cdf(self, exporter, client, dry_run)
#      71 def export_to_cdf(self, exporter: CDFExporter, client: NeatClient, dry_run: bool) -> UploadResultList:
# ---> 72     return self._export(
#      73         partial(exporter.export_to_cdf, client=client, dry_run=dry_run), exporter.agent, exporter.description
#      74     )
#
# File ~\Projects\internal\neat\cognite\neat\_store\_rules_store.py:80, in NeatRulesStore._export(self, action, agent, description)
#      78 result = last_entity.result
#      79 if not isinstance(result, OutRules):
# ---> 80     raise NeatValueError(f"Expected OutRules, got {type(result)}")
#      81 rules = result.get_rules()
#      83 result, _ = self._run(lambda: action(rules), agent, last_entity, description)
#
# NeatValueError: Expected OutRules, got <class 'cognite.neat._utils.upload.UploadResultList'>

# %% [markdown]
# ## Populate Data Model

# %% [markdown]
# Neat keeps track of the data, so we can immidiately populate this data model with the original data

# %%
neat.to.cdf.instances()
# Out:
# INFO | 2024-12-06 15:07:42,383 | Staring DMSLoader and will process 1 views.
# INFO | 2024-12-06 15:07:42,384 | Starting ViewId(space='sp_doctrino', external_id='Asset', version='v1') 1/1.
# INFO | 2024-12-06 15:07:46,612 | Finished ViewId(space='sp_doctrino', external_id='Asset', version='v1').
# You can inspect the details with the .inspect.outcome.instances(...) method.
# [UploadResult(name='Asset', error_messages=[], issues=[], created={NodeId(space='sp_doctrino_instances', external_id='1000000000710374.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000708792.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000284994.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000681224.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000042272.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000285145.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000682253.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000717626.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000822822.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000716786.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000112476.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000706879.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000250910.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000112705.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000280877.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000285013.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000180031.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000715145.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000717627.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000112515.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000682345.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000930092.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000705705.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000708176.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000291740.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000710031.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000705444.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000708793.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000706875.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000716642.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000291798.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000684149.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000716805.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000112501.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000285043.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000112396.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000709122.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000284937.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000292008.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000705479.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000716882.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000705450.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000964377.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000112473.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000716830.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000293776.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000712757.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000291726.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000291708.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000285037.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000763521.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000284925.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000683310.0'), NodeId(space='sp_doctrino_instances', external_id='1000000000822 ...

# %% [markdown]
# <img src="../../artifacts/figs/working_with_metadata_published_dm.png" width="1200">
