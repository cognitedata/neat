# %% [markdown]
# # CSV Onboarding
#
# **Prerequisite**:
#
# - Installed Neat, see [Installation](../../gettingstarted/installation.html)
# - Launched a notebook environment.
# - Familiar with the `NeatSession` object, see [introduction](../introduction/introduction.html)
# - Access to `NeatEngine`
#
#
#
# In this tutorial, we will load data from a `csv`, infer a data model from the data and push the model with data to CDF.

# %% [markdown]
# ## Reading Metadata

# %% [markdown]
# We will start by instansiating a `NeatSession` and read the data from an URL.

# %%
from cognite.neat import NeatSession, get_cognite_client

# %%
neat = NeatSession(get_cognite_client(".env"))
# Out:
# Found .env file in repository root. Loaded variables from .env file.
# Neat Engine 2.0.3 loaded.

# %% [markdown]
# A snippet of the data we are reading are shown below
#
#
# ```csv
# ELC_STATUS_ID,RES_ID,SOURCE_DB,SOURCE_TABLE,WMT_AREA_ID,WMT_CATEGORY_ID,WMT_CONTRACTOR_ID,WMT_FUNC_CODE_ID,WMT_LOCATION_ID,WMT_PO_ID,WMT_SAFETYCRITICALELEMENT_ID,WMT_SYSTEM_ID,WMT_TAG_CREATED_DATE,WMT_TAG_CRITICALLINE,WMT_TAG_DESC,WMT_TAG_GLOBALID,WMT_TAG_HISTORYREQUIRED,WMT_TAG_ID,WMT_TAG_ID_ANCESTOR,WMT_TAG_ISACTIVE,WMT_TAG_ISOWNEDBYPROJECT,WMT_TAG_LOOP,WMT_TAG_MAINID,WMT_TAG_NAME,WMT_TAG_UPDATED_BY,WMT_TAG_UPDATED_DATE,WMT_TAG_STATUSCHGDATE,WMT_TAG_COMMENT,WMT_TAG_SUFFIX,WMT_SYSTEM_ACTIVE,WMT_SYSTEM_CODE,WMT_SYSTEM_DESC,WMT_SYSTEM_NAME,WMT_LOCATION_ACTIVE,WMT_LOCATION_CODE,WMT_LOCATION_EXTENDACTIVEWOP,WMT_LOCATION_EXTERNALOWNERSHIP,WMT_LOCATION_MAITIS,WMT_LOCATION_NAME,WMT_LOCATION_NOCOPIESDEFAULTIC,WMT_LOCATION_NOCOPIESWOPERMIT,WMT_LOCATION_OPERATIONHOURS,WMT_LOCATION_PROGVALUE,WMT_LOCATION_SIMULATETIMEFRAME,WMT_LOCATION_SJAMAXNOOFTASKS,WMT_LOCATION_USEPLOTALTITUDE,WMT_LOCATION_WORKSTART,latestUpdateTimeSource
# 1211,525283,workmate,wmate_dba.wmt_tag,1600,1116,1686,4564,1004,8309,1060,4440,26/06/2009 15:36,N,VRD - PH 1STSTGGEAR THRUST BRG OUT,1000000000681024,Y,346434,345637,1,0,96116,681760,23-TE-96116-04,8137,11/07/2014 09:25,,,,,,,,,,,,,,,,,,,,,,
# 1211,532924,workmate,wmate_dba.wmt_tag,1600,1116,1686,4564,1004,8309,1060,4440,26/06/2009 15:36,N,VRD - PH 1STSTG COMP SEAL GAS HTR,1000000000682252,Y,346452,346633,1,0,96148,681760,23-TE-96148,8137,11/07/2014 09:25,,,,,,,,,,,,,,,,,,,,,,
# 1211,446683,workmate,wmate_dba.wmt_tag,1600,1116,1686,4627,1004,8309,1060,4440,26/06/2009 15:36,N,VRD - PH 1STSTGGEAR 1 JOURNBRG DE,1000000000715794,Y,346995,346935,1,0,96117,681760,23-YT-96117-01,9802,09/12/2013 12:53,,,,,,,,,,,,,,,,,,,,,,
# 1211,,workmate,wmate_dba.wmt_tag,1600,1152,1686,11275,1004,,,4440,13/12/2012 14:13,N,SOFT TAG VRD - PH 1STSTG PRIM SEAL LEAK DE,1000000000250739,Y,682956,345868,1,0,,681760,23-FI-96151,1001,09/10/2015 11:56,06/10/2014 07:45,,,,,,,,,,,,,,,,,,,,,
# ```

# %% [markdown]
# To read a `csv`, we need to tell neat what typ of data is in the source, as well as which column is the identifier.
#
# We know that this data contains assets and that the column `WMT_TAG_GLOBALID` is the unique identifier of these assets.

# %%
url = "https://apps-cdn.cogniteapp.com/toolkit/publicdata/assets.Table.csv"

# %%
neat.read.csv(url, type="Asset", primary_key="WMT_TAG_GLOBALID")

# %%
neat
# Out:
# <H2>Instances</H2> <br /><strong>Overview</strong>:<ul><li>1 named graphs</strong></li><li>Total of 1 unique types</strong></li><li>1103 instances in default graph</strong></li></ul><br /><strong>default graph</strong>:<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Occurrence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Asset</td>
#       <td>1103</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><strong>Provenance</strong>:<ul><li>Initialize graph store as OxigraphStore</li><li>Extracted triples to named graph urn:x-rdflib:default using CSVExtractor</li></ul>

# %% [markdown]
# Studying the output above, we see that we succesfully read 1103 assets into the `NeatSession`.

# %% [markdown]
# ## Infer Data Model

# %% [markdown]
# We can infer a data model from data in the `NeatSession` by calling `.infer()`.

# %%
neat.infer()
# Out:
# []

# %%
neat
# Out:
# <H2>Data Model</H2><br /><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>type</th>
#       <td>Logical Data Model</td>
#     </tr>
#     <tr>
#       <th>intended for</th>
#       <td>Information Architect</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>Inferred Model</td>
#     </tr>
#     <tr>
#       <th>external_id</th>
#       <td>NeatInferredDataModel</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>v1</td>
#     </tr>
#     <tr>
#       <th>classes</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>properties</th>
#       <td>29</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><H2>Instances</H2> <br /><strong>Overview</strong>:<ul><li>1 named graphs</strong></li><li>Total of 1 unique types</strong></li><li>1103 instances in default graph</strong></li></ul><br /><strong>default graph</strong>:<div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Occurrence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Asset</td>
#       <td>1103</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><strong>Provenance</strong>:<ul><li>Initialize graph store as OxigraphStore</li><li>Extracted triples to named graph urn:x-rdflib:default using CSVExtractor</li></ul>

# %% [markdown]
# ## Inspect Data Model

# %%
neat.inspect.properties()
# Out:
#               class_                     property_ value_type  max_count  \
# 0   neat_space:Asset                WMT_TAG_MAINID       long          1
# 1   neat_space:Asset                  WMT_TAG_DESC     string          1
# 2   neat_space:Asset               WMT_CATEGORY_ID       long          1
# 3   neat_space:Asset               WMT_LOCATION_ID       long          1
# 4   neat_space:Asset          WMT_TAG_CRITICALLINE     string          1
# 5   neat_space:Asset              WMT_TAG_ISACTIVE       long          1
# 6   neat_space:Asset              WMT_TAG_GLOBALID       long          1
# 7   neat_space:Asset              WMT_FUNC_CODE_ID       long          1
# 8   neat_space:Asset      WMT_TAG_ISOWNEDBYPROJECT       long          1
# 9   neat_space:Asset       WMT_TAG_HISTORYREQUIRED     string          1
# 10  neat_space:Asset                  SOURCE_TABLE     string          1
# 11  neat_space:Asset                    WMT_TAG_ID       long          1
# 12  neat_space:Asset               WMT_TAG_COMMENT     string          1
# 13  neat_space:Asset          WMT_TAG_UPDATED_DATE     string          1
# 14  neat_space:Asset                  WMT_TAG_NAME     string          1
# 15  neat_space:Asset                 ELC_STATUS_ID       long          1
# 16  neat_space:Asset                   WMT_AREA_ID       long          1
# 17  neat_space:Asset           WMT_TAG_ID_ANCESTOR       long          1
# 18  neat_space:Asset                 WMT_SYSTEM_ID       long          1
# 19  neat_space:Asset          WMT_TAG_CREATED_DATE   dateTime          1
# 20  neat_space:Asset                     SOURCE_DB     string          1
# 21  neat_space:Asset            WMT_TAG_UPDATED_BY       long          1
# 22  neat_space:Asset             WMT_CONTRACTOR_ID       long          1
# 23  neat_space:Asset                     WMT_PO_ID       long          1
# 24  neat_space:Asset                  WMT_TAG_LOOP     string          1
# 25  neat_space:Asset                        RES_ID       long          1
# 26  neat_space:Asset  WMT_SAFETYCRITICALELEMENT_ID       long          1
# 27  neat_space:Asset         WMT_TAG_STATUSCHGDATE     string          1
# 28  neat_space:Asset                WMT_TAG_SUFFIX     string          1
#
#                                       instance_source
# 0           prefix_16:Asset(prefix_16:WMT_TAG_MAINID)
# 1             prefix_16:Asset(prefix_16:WMT_TAG_DESC)
# 2          prefix_16:Asset(prefix_16:WMT_CATEGORY_ID)
# 3          prefix_16:Asset(prefix_16:WMT_LOCATION_ID)
# 4     prefix_16:Asset(prefix_16:WMT_TAG_CRITICALLINE)
# 5         prefix_16:Asset(prefix_16:WMT_TAG_ISACTIVE)
# 6         prefix_16:Asset(prefix_16:WMT_TAG_GLOBALID)
# 7         prefix_16:Asset(prefix_16:WMT_FUNC_CODE_ID)
# 8   prefix_16:Asset(prefix_16:WMT_TAG_ISOWNEDBYPRO...
# 9   prefix_16:Asset(prefix_16:WMT_TAG_HISTORYREQUI...
# 10            prefix_16:Asset(prefix_16:SOURCE_TABLE)
# 11              prefix_16:Asset(prefix_16:WMT_TAG_ID)
# 12         prefix_16:Asset(prefix_16:WMT_TAG_COMMENT)
# 13    prefix_16:Asset(prefix_16:WMT_TAG_UPDATED_DATE)
# 14            prefix_16:Asset(prefix_16:WMT_TAG_NAME)
# 15           prefix_16:Asset(prefix_16:ELC_STATUS_ID)
# 16             prefix_16:Asset(prefix_16:WMT_AREA_ID)
# 17     prefix_16:Asset(prefix_16:WMT_TAG_ID_ANCESTOR)
# 18           prefix_16:Asset(prefix_16:WMT_SYSTEM_ID)
# 19    prefix_16:Asset(prefix_16:WMT_TAG_CREATED_DATE)
# 20               prefix_16:Asset(prefix_16:SOURCE_DB)
# 21      prefix_16:Asset(prefix_16:WMT_TAG_UPDATED_BY)
# 22       prefix_16:Asset(prefix_16:WMT_CONTRACTOR_ID)
# 23               prefix_16:Asset(prefix_16:WMT_PO_ID)
# 24            prefix_16:Asset(prefix_16:WMT_TAG_LOOP)
# 25                  prefix_16:Asset(prefix_16:RES_ID)
# 26  prefix_16:Asset(prefix_16:WMT_SAFETYCRITICALEL...
# 27   prefix_16:Asset(prefix_16:WMT_TAG_STATUSCHGDATE)
# 28          prefix_16:Asset(prefix_16:WMT_TAG_SUFFIX)

# %% [markdown]
# After inspecting the properties, we notice that we have a `Logical Data Model`. This cannot be written to CDF. To do that we will convert it to the `dms` format
# which is what CDF expects for data models.

# %% [markdown]
# ## Convert Data Model

# %%
neat.convert()
# Out:
# Rules converted to dms
# []

# %%
neat.inspect.properties
# Out:
#                             view                 view_property value_type  \
# 0   neat_space:Asset(version=v1)                WMT_TAG_MAINID      int64
# 1   neat_space:Asset(version=v1)                  WMT_TAG_DESC       text
# 2   neat_space:Asset(version=v1)               WMT_CATEGORY_ID      int64
# 3   neat_space:Asset(version=v1)               WMT_LOCATION_ID      int64
# 4   neat_space:Asset(version=v1)          WMT_TAG_CRITICALLINE       text
# 5   neat_space:Asset(version=v1)              WMT_TAG_ISACTIVE      int64
# 6   neat_space:Asset(version=v1)              WMT_TAG_GLOBALID      int64
# 7   neat_space:Asset(version=v1)              WMT_FUNC_CODE_ID      int64
# 8   neat_space:Asset(version=v1)      WMT_TAG_ISOWNEDBYPROJECT      int64
# 9   neat_space:Asset(version=v1)       WMT_TAG_HISTORYREQUIRED       text
# 10  neat_space:Asset(version=v1)                  SOURCE_TABLE       text
# 11  neat_space:Asset(version=v1)                    WMT_TAG_ID      int64
# 12  neat_space:Asset(version=v1)               WMT_TAG_COMMENT       text
# 13  neat_space:Asset(version=v1)          WMT_TAG_UPDATED_DATE       text
# 14  neat_space:Asset(version=v1)                  WMT_TAG_NAME       text
# 15  neat_space:Asset(version=v1)                 ELC_STATUS_ID      int64
# 16  neat_space:Asset(version=v1)                   WMT_AREA_ID      int64
# 17  neat_space:Asset(version=v1)           WMT_TAG_ID_ANCESTOR      int64
# 18  neat_space:Asset(version=v1)                 WMT_SYSTEM_ID      int64
# 19  neat_space:Asset(version=v1)          WMT_TAG_CREATED_DATE  timestamp
# 20  neat_space:Asset(version=v1)                     SOURCE_DB       text
# 21  neat_space:Asset(version=v1)            WMT_TAG_UPDATED_BY      int64
# 22  neat_space:Asset(version=v1)             WMT_CONTRACTOR_ID      int64
# 23  neat_space:Asset(version=v1)                     WMT_PO_ID      int64
# 24  neat_space:Asset(version=v1)                  WMT_TAG_LOOP       text
# 25  neat_space:Asset(version=v1)                        RES_ID      int64
# 26  neat_space:Asset(version=v1)  WMT_SAFETYCRITICALELEMENT_ID      int64
# 27  neat_space:Asset(version=v1)         WMT_TAG_STATUSCHGDATE       text
# 28  neat_space:Asset(version=v1)                WMT_TAG_SUFFIX       text
#
#     nullable  is_list         container            container_property  \
# 0       True    False  neat_space:Asset                WMT_TAG_MAINID
# 1       True    False  neat_space:Asset                  WMT_TAG_DESC
# 2       True    False  neat_space:Asset               WMT_CATEGORY_ID
# 3       True    False  neat_space:Asset               WMT_LOCATION_ID
# 4       True    False  neat_space:Asset          WMT_TAG_CRITICALLINE
# 5       True    False  neat_space:Asset              WMT_TAG_ISACTIVE
# 6       True    False  neat_space:Asset              WMT_TAG_GLOBALID
# 7       True    False  neat_space:Asset              WMT_FUNC_CODE_ID
# 8       True    False  neat_space:Asset      WMT_TAG_ISOWNEDBYPROJECT
# 9       True    False  neat_space:Asset       WMT_TAG_HISTORYREQUIRED
# 10      True    False  neat_space:Asset                  SOURCE_TABLE
# 11      True    False  neat_space:Asset                    WMT_TAG_ID
# 12      True    False  neat_space:Asset               WMT_TAG_COMMENT
# 13      True    False  neat_space:Asset          WMT_TAG_UPDATED_DATE
# 14      True    False  neat_space:Asset                  WMT_TAG_NAME
# 15      True    False  neat_space:Asset                 ELC_STATUS_ID
# 16      True    False  neat_space:Asset                   WMT_AREA_ID
# 17      True    False  neat_space:Asset           WMT_TAG_ID_ANCESTOR
# 18      True    False  neat_space:Asset                 WMT_SYSTEM_ID
# 19      True    False  neat_space:Asset          WMT_TAG_CREATED_DATE
# 20      True    False  neat_space:Asset                     SOURCE_DB
# 21      True    False  neat_space:Asset            WMT_TAG_UPDATED_BY
# 22      True    False  neat_space:Asset             WMT_CONTRACTOR_ID
# 23      True    False  neat_space:Asset                     WMT_PO_ID
# 24      True    False  neat_space:Asset                  WMT_TAG_LOOP
# 25      True    False  neat_space:Asset                        RES_ID
# 26      True    False  neat_space:Asset  WMT_SAFETYCRITICALELEMENT_ID
# 27      True    False  neat_space:Asset         WMT_TAG_STATUSCHGDATE
# 28      True    False  neat_space:Asset                WMT_TAG_SUFFIX
#
#                                               logical
# 0   http://purl.org/cognite/neat/data-model/verifi...
# 1   http://purl.org/cognite/neat/data-model/verifi...
# 2   http://purl.org/cognite/neat/data-model/verifi...
# 3   http://purl.org/cognite/neat/data-model/verifi...
# 4   http://purl.org/cognite/neat/data-model/verifi...
# 5   http://purl.org/cognite/neat/data-model/verifi...
# 6   http://purl.org/cognite/neat/data-model/verifi...
# 7   http://purl.org/cognite/neat/data-model/verifi...
# 8   http://purl.org/cognite/neat/data-model/verifi...
# 9   http://purl.org/cognite/neat/data-model/verifi...
# 10  http://purl.org/cognite/neat/data-model/verifi...
# 11  http://purl.org/cognite/neat/data-model/verifi...
# 12  http://purl.org/cognite/neat/data-model/verifi...
# 13  http://purl.org/cognite/neat/data-model/verifi...
# 14  http://purl.org/cognite/neat/data-model/verifi...
# 15  http://purl.org/cognite/neat/data-model/verifi...
# 16  http://purl.org/cognite/neat/data-model/verifi...
# 17  http://purl.org/cognite/neat/data-model/verifi...
# 18  http://purl.org/cognite/neat/data-model/verifi...
# 19  http://purl.org/cognite/neat/data-model/verifi...
# 20  http://purl.org/cognite/neat/data-model/verifi...
# 21  http://purl.org/cognite/neat/data-model/verifi...
# 22  http://purl.org/cognite/neat/data-model/verifi...
# 23  http://purl.org/cognite/neat/data-model/verifi...
# 24  http://purl.org/cognite/neat/data-model/verifi...
# 25  http://purl.org/cognite/neat/data-model/verifi...
# 26  http://purl.org/cognite/neat/data-model/verifi...
# 27  http://purl.org/cognite/neat/data-model/verifi...
# 28  http://purl.org/cognite/neat/data-model/verifi...

# %% [markdown]
# Now we see that we have information about how the data model is implemented.
#
# We can further show the steps we have been taking so far, called the provenance of the data model.

# %%
neat.show.data_model.provenance()
# Out:
# data_model_provenance_95e2e718.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="data_model_provenance_95e2e718.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# We notice that we get the default space and model identifier, so we set it to be unique.

# %% [markdown]
# ## Publish Data Model

# %%
neat.set.data_model_id(("sp_doctrino", "DoctrinoAssetModel", "v1"))
# Out:
# []

# %% [markdown]
# Now we are ready to publish this to CDF.

# %%
neat.to.cdf.data_model(existing="recreate")
# Out:
# You can inspect the details with the .inspect.outcome.data_model(...) method.
# [UploadResult(name='spaces', error_messages=[], issues=[], created=set(), upserted=set(), deleted=set(), changed=set(), unchanged={'sp_doctrino'}, skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set()),
#  UploadResult(name='containers', error_messages=[], issues=[], created=set(), upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped={ContainerId(space='sp_doctrino', external_id='Asset')}, failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set()),
#  UploadResult(name='views', error_messages=[], issues=[], created={ViewId(space='sp_doctrino', external_id='Asset', version='v1')}, upserted=set(), deleted={ViewId(space='sp_doctrino', external_id='Asset', version='v1')}, changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set()),
#  UploadResult(name='data_models', error_messages=[], issues=[], created={DataModelId(space='sp_doctrino', external_id='DoctrinoAssetModel', version='v1')}, upserted=set(), deleted={DataModelId(space='sp_doctrino', external_id='DoctrinoAssetModel', version='v1')}, changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set()),
#  UploadResult(name='nodes', error_messages=[], issues=[], created=set(), upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set())]

# %% [markdown]
# ## Populate Data Model

# %% [markdown]
# Neat keeps track of the data, so we can immidiately populate this data model with the original data

# %%
neat.to.cdf.instances()
# Out:
# INFO | 2025-01-26 14:18:14,262 | Staring DMSLoader and will process 1 views.
# INFO | 2025-01-26 14:18:14,290 | Starting ViewId(space='sp_doctrino', external_id='Asset', version='v1') 1/1.
# Loading ViewId(space='sp_doctrino', external_id='Asset', version='v1'): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1103/1103 [00:02<00:00, 478.40it/s]
# INFO | 2025-01-26 14:18:16,637 | Finished ViewId(space='sp_doctrino', external_id='Asset', version='v1').
# You can inspect the details with the .inspect.outcome.instances(...) method.
# [UploadResult(name='Asset', error_messages=[], issues=[], created=set(), upserted=set(), deleted=set(), changed=set(), unchanged={NodeId(space='sp_doctrino_instances', external_id='1000000000291956'), NodeId(space='sp_doctrino_instances', external_id='1000000000964378'), NodeId(space='sp_doctrino_instances', external_id='1000000000284939'), NodeId(space='sp_doctrino_instances', external_id='1000000000711870'), NodeId(space='sp_doctrino_instances', external_id='1000000000685301'), NodeId(space='sp_doctrino_instances', external_id='1000000000718452'), NodeId(space='sp_doctrino_instances', external_id='1000000000228480'), NodeId(space='sp_doctrino_instances', external_id='1000000000179951'), NodeId(space='sp_doctrino_instances', external_id='1000000000708480'), NodeId(space='sp_doctrino_instances', external_id='1000000000251067'), NodeId(space='sp_doctrino_instances', external_id='1000000000717383'), NodeId(space='sp_doctrino_instances', external_id='1000000000285020'), NodeId(space='sp_doctrino_instances', external_id='1000000000681027'), NodeId(space='sp_doctrino_instances', external_id='1000000000682050'), NodeId(space='sp_doctrino_instances', external_id='1000000000682344'), NodeId(space='sp_doctrino_instances', external_id='1000000000716646'), NodeId(space='sp_doctrino_instances', external_id='1000000000250958'), NodeId(space='sp_doctrino_instances', external_id='1000000000228837'), NodeId(space='sp_doctrino_instances', external_id='1000000000682348'), NodeId(space='sp_doctrino_instances', external_id='1000000000250947'), NodeId(space='sp_doctrino_instances', external_id='1000000000705439'), NodeId(space='sp_doctrino_instances', external_id='1000000000112740'), NodeId(space='sp_doctrino_instances', external_id='1000000000706869'), NodeId(space='sp_doctrino_instances', external_id='1000000000291871'), NodeId(space='sp_doctrino_instances', external_id='1000000000285714'), NodeId(space='sp_doctrino_instances', external_id='1000000000250908'), NodeId(space='sp_doctrino_instances', external_id='1000000000685079'), NodeId(space='sp_doctrino_instances', external_id='1000000000230417'), NodeId(space='sp_doctrino_instances', external_id='1000000000706781'), NodeId(space='sp_doctrino_instances', external_id='1000000000709866'), NodeId(space='sp_doctrino_instances', external_id='1000000000681227'), NodeId(space='sp_doctrino_instances', external_id='1000000000706870'), NodeId(space='sp_doctrino_instances', external_id='1000000000683753'), NodeId(space='sp_doctrino_instances', external_id='1000000000716643'), NodeId(space='sp_doctrino_instances', external_id='1000000000228329'), NodeId(space='sp_doctrino_instances', external_id='1000000000250780'), NodeId(space='sp_doctrino_instances', external_id='1000000000291811'), NodeId(space='sp_doctrino_instances', external_id='1000000000717551'), NodeId(space='sp_doctrino_instances', external_id='1000000000707902'), NodeId(space='sp_doctrino_instances', external_id='1000000000708815'), NodeId(space='sp_doctrino_instances', external_id='1000000000179843'), NodeId(space='sp_doctrino_instances', external_id='1000000000250831'), NodeId(space='sp_doctrino_instances', external_id='1000000000717374'), NodeId(space='sp_doctrino_instances', external_id='1000000000292000'), NodeId(space='sp_doctrino_instances', external_id='1000000000251064'), NodeId(space='sp_doctrino_instances', external_id='1000000000716797'), NodeId(space='sp_doctrino_instances', external_id='1000000000112704'), NodeId(space='sp_doctrino_instances', external_id='1000000000717629'), NodeId(space='sp_doctrino_instances', external_id='1000000000717637'), NodeId(space='sp_doctrino_instances', external_id='1000000000715798'), NodeId(space='sp_doctrino_instances', external_id='1000000000112738'), NodeId(space='sp_doctrino_instances', external_id='1000000000705418'), NodeId(space='sp_doctrino_instances', external_id='1000000000250731'), NodeId(space='sp_doctrino_instances', external_id='1000000000112421'), NodeId(space='sp_doctrino_instances' ...

# %% [markdown]
# <img src="../../artifacts/figs/working_with_metadata_published_dm.png" width="1200">
