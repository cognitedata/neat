# %% [markdown]
# ## From Source to CDF: Nordic44 Use-Case
#
# **Prerequisite**:
#
# - Access to a CDF Project.
# - Know how to install and setup Python.
# - Launch a Python notebook.
#
# In this tutorial we will show how to onboard source data to CDF. We will:
# - read in Nordic44 data, containing instances of the nordic power system in the form of RDF triples.
# - infer the underlying data model
# - prepare data model to be CDF compliant
# - upload data model to CDF
# - populate data model with instances from the Nordic44 data

# %%
from cognite.neat import NeatSession, get_cognite_client

# %%
client = get_cognite_client(".env")
# Out:
# Found .env file in repository root. Loaded variables from .env file.

# %%
neat = NeatSession(client, verbose=True)

# %% [markdown]
# We have already nordic44 as an example in neat and we can read it in as following:

# %%
neat.read.rdf.examples.nordic44
# Out:
# []

# %% [markdown]
# Let's inspect content of the NEAT session:

# %%
neat
# Out:
# <H2>Instances</H2> <br /><strong>Overview</strong>:<ul><li>59 types</strong></li><li>2713 instances</strong></li></ul><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Occurrence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CurrentLimit</td>
#       <td>530</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Terminal</td>
#       <td>452</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>OperationalLimitSet</td>
#       <td>238</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OperatingShare</td>
#       <td>207</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>VoltageLimit</td>
#       <td>184</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>PowerTransferCorridor</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><strong>Provenance</strong>:<ul><li>Initialize graph store as Memory</li><li>Extracted triples to graph store using RdfFileExtractor</li></ul>

# %% [markdown]
# Neat provides you a way also to visualize instances:

# %%
neat.show.instances()
# Out:
# Max of 100 nodes and edges are displayed, which are randomly selected.
# CytoscapeWidget(cytoscape_layout={'name': 'cola'}, cytoscape_style=[{'selector': 'edge', 'style': {'width': 1,…

# %% [markdown]
# Let's now infer data model from the instances (this take with in-memory graph store ~ 20s).
#
# The inference will produce un-validated logical data model (aka [Information Rules](https://cognite-neat.readthedocs-hosted.com/en/latest/tutorials/data-modeling-lifecycle/part-1-knowledge-acquisition.html#information-architect-david)), which we will later prepare for validation and later conversion to physical data model (aka [DMS Rules](https://cognite-neat.readthedocs-hosted.com/en/latest/tutorials/data-modeling-lifecycle/part-1-knowledge-acquisition.html#dms-architect-alice))

# %%
issues = neat.infer()
# Out:
# Data Model Inference <class 'cognite.neat._store._base.NeatGraphStore'> <cognite.neat._store._base.NeatGraphStore object at 0x118ec7d50> read successfully

# %% [markdown]
# Now if we inspect session you will beside instances overview also metadata about the inferred data model:

# %%
neat
# Out:
# <H2>Raw Data Model</H2><br /><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>dataModelType</th>
#       <td>enterprise</td>
#     </tr>
#     <tr>
#       <th>schema</th>
#       <td>partial</td>
#     </tr>
#     <tr>
#       <th>extension</th>
#       <td>addition</td>
#     </tr>
#     <tr>
#       <th>prefix</th>
#       <td>inference_space</td>
#     </tr>
#     <tr>
#       <th>namespace</th>
#       <td>http://purl.org/cognite/neat#</td>
#     </tr>
#     <tr>
#       <th>title</th>
#       <td>InferredDataModel</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>Inferred model from knowledge graph</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>v1</td>
#     </tr>
#     <tr>
#       <th>created</th>
#       <td>2024-10-28 16:55:20.096865</td>
#     </tr>
#     <tr>
#       <th>updated</th>
#       <td>2024-10-28 16:55:20.096870</td>
#     </tr>
#     <tr>
#       <th>creator</th>
#       <td>NEAT</td>
#     </tr>
#     <tr>
#       <th>license</th>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>rights</th>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><H2>Instances</H2> <br /><strong>Overview</strong>:<ul><li>59 types</strong></li><li>2713 instances</strong></li></ul><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Occurrence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CurrentLimit</td>
#       <td>530</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Terminal</td>
#       <td>452</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>OperationalLimitSet</td>
#       <td>238</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OperatingShare</td>
#       <td>207</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>VoltageLimit</td>
#       <td>184</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>PowerTransferCorridor</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><strong>Provenance</strong>:<ul><li>Initialize graph store as Memory</li><li>Extracted triples to graph store using RdfFileExtractor</li></ul>

# %% [markdown]
# Since the inferred data model might contain external_ids of properties and objects which are not compliant with cdf we need to prepare it prior validation and conversion to cdf compliant data model. This can be done by running:

# %%
neat.prepare.data_model.cdf_compliant_external_ids()

# %%
neat.verify()
# Out:
# []

# %% [markdown]
# After running verify we can see that we now have a verified data model in neat session:

# %%
neat
# Out:
# <H2>Data Model</H2><br /><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>role</th>
#       <td>information architect</td>
#     </tr>
#     <tr>
#       <th>data_model_type</th>
#       <td>enterprise</td>
#     </tr>
#     <tr>
#       <th>schema_</th>
#       <td>partial</td>
#     </tr>
#     <tr>
#       <th>extension</th>
#       <td>addition</td>
#     </tr>
#     <tr>
#       <th>prefix</th>
#       <td>inference_space</td>
#     </tr>
#     <tr>
#       <th>namespace</th>
#       <td>http://purl.org/cognite/neat#</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>InferredDataModel</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>Inferred model from knowledge graph</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>v1</td>
#     </tr>
#     <tr>
#       <th>created</th>
#       <td>2024-10-28 16:55:20.096865</td>
#     </tr>
#     <tr>
#       <th>updated</th>
#       <td>2024-10-28 16:55:20.096870</td>
#     </tr>
#     <tr>
#       <th>creator</th>
#       <td>NEAT</td>
#     </tr>
#     <tr>
#       <th>license</th>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>rights</th>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><H2>Instances</H2> <br /><strong>Overview</strong>:<ul><li>59 types</strong></li><li>2713 instances</strong></li></ul><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Occurrence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CurrentLimit</td>
#       <td>530</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Terminal</td>
#       <td>452</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>OperationalLimitSet</td>
#       <td>238</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OperatingShare</td>
#       <td>207</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>VoltageLimit</td>
#       <td>184</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>PowerTransferCorridor</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><strong>Provenance</strong>:<ul><li>Initialize graph store as Memory</li><li>Extracted triples to graph store using RdfFileExtractor</li><li>Added rules to graph store as InformationRules</li><li>Upsert prefixes to graph store</li></ul>

# %% [markdown]
# Similar to the instances we can visualize the data model:

# %%
neat.show.data_model()
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'cola'}, cytoscape_style=[{'selector': 'node', 'css': {'content': 'd…

# %% [markdown]
# Now let's convert the verified data model to be CDF complian data model (aka physical data model)

# %%
neat.convert("dms")
# Out:
# Rules converted to dms

# %%
neat
# Out:
# <H2>Data Model</H2><br /><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>role</th>
#       <td>DMS Architect</td>
#     </tr>
#     <tr>
#       <th>data_model_type</th>
#       <td>enterprise</td>
#     </tr>
#     <tr>
#       <th>schema_</th>
#       <td>partial</td>
#     </tr>
#     <tr>
#       <th>extension</th>
#       <td>addition</td>
#     </tr>
#     <tr>
#       <th>space</th>
#       <td>inference_space</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>InferredDataModel</td>
#     </tr>
#     <tr>
#       <th>description</th>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>external_id</th>
#       <td>inferreddatamodel</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>v1</td>
#     </tr>
#     <tr>
#       <th>creator</th>
#       <td>NEAT</td>
#     </tr>
#     <tr>
#       <th>created</th>
#       <td>2024-10-28 16:55:20.096865</td>
#     </tr>
#     <tr>
#       <th>updated</th>
#       <td>2024-10-28 16:55:20.096870</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><H2>Instances</H2> <br /><strong>Overview</strong>:<ul><li>59 types</strong></li><li>2713 instances</strong></li></ul><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Occurrence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CurrentLimit</td>
#       <td>530</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Terminal</td>
#       <td>452</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>OperationalLimitSet</td>
#       <td>238</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OperatingShare</td>
#       <td>207</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>VoltageLimit</td>
#       <td>184</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>PowerTransferCorridor</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div><br /><strong>Provenance</strong>:<ul><li>Initialize graph store as Memory</li><li>Extracted triples to graph store using RdfFileExtractor</li><li>Added rules to graph store as InformationRules</li><li>Upsert prefixes to graph store</li></ul>

# %% [markdown]
# Now we have all the components to form knowledge graph in CDF, i.e. data model and instances. Let's upload them to CDF:

# %%
neat.to.cdf.data_model()
# Out:
# [UploadResult(name='spaces', error_messages=[], issues=[], created={'inference_space'}, upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set()),
#  UploadResult(name='containers', error_messages=[], issues=[], created={ContainerId(space='inference_space', external_id='GeneratingUnit'), ContainerId(space='inference_space', external_id='AnalogValue'), ContainerId(space='inference_space', external_id='ControlArea'), ContainerId(space='inference_space', external_id='LineCircuit'), ContainerId(space='inference_space', external_id='LoadResponseCharacteristic'), ContainerId(space='inference_space', external_id='Gate'), ContainerId(space='inference_space', external_id='ProtectiveActionAdjustment'), ContainerId(space='inference_space', external_id='ActivePowerLimit'), ContainerId(space='inference_space', external_id='RatioTapChanger'), ContainerId(space='inference_space', external_id='NonConformLoadGroup'), ContainerId(space='inference_space', external_id='EnergySchedulingArea'), ContainerId(space='inference_space', external_id='PowerTransformerEnd'), ContainerId(space='inference_space', external_id='Substation'), ContainerId(space='inference_space', external_id='ACLineSegment'), ContainerId(space='inference_space', external_id='OperationalLimitType'), ContainerId(space='inference_space', external_id='ControlAreaGeneratingUnit'), ContainerId(space='inference_space', external_id='LinearShuntCompensator'), ContainerId(space='inference_space', external_id='RemedialActionScheme'), ContainerId(space='inference_space', external_id='MeasurementValueSource'), ContainerId(space='inference_space', external_id='CircuitShare'), ContainerId(space='inference_space', external_id='OperatingShare'), ContainerId(space='inference_space', external_id='Stage'), ContainerId(space='inference_space', external_id='PowerTransferCorridor'), ContainerId(space='inference_space', external_id='SubLoadArea'), ContainerId(space='inference_space', external_id='OperatingParticipant'), ContainerId(space='inference_space', external_id='ConformLoad'), ContainerId(space='inference_space', external_id='BaseVoltage'), ContainerId(space='inference_space', external_id='ConnectivityNode'), ContainerId(space='inference_space', external_id='Line'), ContainerId(space='inference_space', external_id='TapChangerControl'), ContainerId(space='inference_space', external_id='BasePower'), ContainerId(space='inference_space', external_id='RegulatingControl'), ContainerId(space='inference_space', external_id='PowerTransformer'), ContainerId(space='inference_space', external_id='Terminal'), ContainerId(space='inference_space', external_id='SynchronousMachine'), ContainerId(space='inference_space', external_id='LoadArea'), ContainerId(space='inference_space', external_id='RateTemperature'), ContainerId(space='inference_space', external_id='ProtectiveActionEquipment'), ContainerId(space='inference_space', external_id='Bay'), ContainerId(space='inference_space', external_id='StageTrigger'), ContainerId(space='inference_space', external_id='SubGeographicalRegion'), ContainerId(space='inference_space', external_id='PinGate'), ContainerId(space='inference_space', external_id='Breaker'), ContainerId(space='inference_space', external_id='FullModel'), ContainerId(space='inference_space', external_id='GeographicalRegion'), ContainerId(space='inference_space', external_id='Analog'), ContainerId(space='inference_space', external_id='VoltageLevel'), ContainerId(space='inference_space', external_id='CurrentLimit'), ContainerId(space='inference_space', external_id='PinEquipment'), ContainerId(space='inference_space', external_id='ProtectiveActionCollection'), ContainerId(space='inference_space', external_id='NonConformLoad'), ContainerId(space='inference_space', external_id='ConformLoadGroup'), ContainerId(space='inference_space', external_id='ScheduleResourceGeneration'), ContainerId(space='inference_space', external_id='OperationalLimitSet'), ContainerId(space='inference_space', external_id='PinTerminal'), ContainerId(space='inference_space', external_id='EnergyCongestionZone'), ContainerId(space='inference_space', external_id='VoltageLimit'), Conta ...
#  UploadResult(name='views', error_messages=[], issues=[], created={ViewId(space='inference_space', external_id='CircuitShare', version='v1'), ViewId(space='inference_space', external_id='PinGate', version='v1'), ViewId(space='inference_space', external_id='OperationalLimitSet', version='v1'), ViewId(space='inference_space', external_id='PowerTransformerEnd', version='v1'), ViewId(space='inference_space', external_id='OperationalLimitType', version='v1'), ViewId(space='inference_space', external_id='Analog', version='v1'), ViewId(space='inference_space', external_id='MeasurementValueSource', version='v1'), ViewId(space='inference_space', external_id='EnergyCongestionZone', version='v1'), ViewId(space='inference_space', external_id='ACLineSegment', version='v1'), ViewId(space='inference_space', external_id='ControlArea', version='v1'), ViewId(space='inference_space', external_id='Stage', version='v1'), ViewId(space='inference_space', external_id='SubGeographicalRegion', version='v1'), ViewId(space='inference_space', external_id='Bay', version='v1'), ViewId(space='inference_space', external_id='BaseVoltage', version='v1'), ViewId(space='inference_space', external_id='VoltageLimit', version='v1'), ViewId(space='inference_space', external_id='ConnectivityNode', version='v1'), ViewId(space='inference_space', external_id='ProtectiveActionEquipment', version='v1'), ViewId(space='inference_space', external_id='LoadArea', version='v1'), ViewId(space='inference_space', external_id='Substation', version='v1'), ViewId(space='inference_space', external_id='ControlAreaGeneratingUnit', version='v1'), ViewId(space='inference_space', external_id='TapChangerControl', version='v1'), ViewId(space='inference_space', external_id='NonConformLoad', version='v1'), ViewId(space='inference_space', external_id='Gate', version='v1'), ViewId(space='inference_space', external_id='RegulatingControl', version='v1'), ViewId(space='inference_space', external_id='ConformLoad', version='v1'), ViewId(space='inference_space', external_id='StageTrigger', version='v1'), ViewId(space='inference_space', external_id='BusbarSection', version='v1'), ViewId(space='inference_space', external_id='GeographicalRegion', version='v1'), ViewId(space='inference_space', external_id='PinTerminal', version='v1'), ViewId(space='inference_space', external_id='LineCircuit', version='v1'), ViewId(space='inference_space', external_id='NonConformLoadGroup', version='v1'), ViewId(space='inference_space', external_id='Line', version='v1'), ViewId(space='inference_space', external_id='VoltageLevel', version='v1'), ViewId(space='inference_space', external_id='PinEquipment', version='v1'), ViewId(space='inference_space', external_id='FullModel', version='v1'), ViewId(space='inference_space', external_id='LinearShuntCompensator', version='v1'), ViewId(space='inference_space', external_id='SynchronousMachine', version='v1'), ViewId(space='inference_space', external_id='Breaker', version='v1'), ViewId(space='inference_space', external_id='RemedialActionScheme', version='v1'), ViewId(space='inference_space', external_id='OperatingShare', version='v1'), ViewId(space='inference_space', external_id='RateTemperature', version='v1'), ViewId(space='inference_space', external_id='GeneratingUnit', version='v1'), ViewId(space='inference_space', external_id='SubLoadArea', version='v1'), ViewId(space='inference_space', external_id='ConformLoadGroup', version='v1'), ViewId(space='inference_space', external_id='CurrentLimit', version='v1'), ViewId(space='inference_space', external_id='AnalogValue', version='v1'), ViewId(space='inference_space', external_id='EnergySchedulingArea', version='v1'), ViewId(space='inference_space', external_id='Disconnector', version='v1'), ViewId(space='inference_space', external_id='ProtectiveActionAdjustment', version='v1'), ViewId(space='inference_space', external_id='Terminal', version='v1'), ViewId(space='inference_space', external_id='BasePower', version='v1'), ViewId(space='in ...
#  UploadResult(name='data_models', error_messages=[], issues=[], created={DataModelId(space='inference_space', external_id='inferreddatamodel', version='v1')}, upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set())]

# %%
neat.to.cdf.instances(space="inference_space")
# Out:
# [UploadResult(name='Nodes', error_messages=[], issues=[], created={NodeId(space='inference_space', external_id='f1769a76-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd90455-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769daf-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769abf-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769e3f-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769d94-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd903d8-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769bca-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769b17-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769b3a-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd90418-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='5831696b-e9e1-8e4a-a169-0e4e09f15f1f'), NodeId(space='inference_space', external_id='f1769b06-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd90382-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd90478-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769b95-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769b47-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd901a4-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769d83-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769b66-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='1ffadccb-2b24-42ba-bdb7-0cd6be979c9c'), NodeId(space='inference_space', external_id='07a05ab2-d780-11e7-9296-cec278b6b50a'), NodeId(space='inference_space', external_id='2dd90399-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='e3ef93a1-723a-224e-8863-472e4f269633'), NodeId(space='inference_space', external_id='2c0e8b5a-a92d-4c43-913b-e5f72b864c46'), NodeId(space='inference_space', external_id='2dd903b8-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd901ff-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd90303-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769db0-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='9241f98a-7ba5-4dd9-8be7-76bb0baf792e'), NodeId(space='inference_space', external_id='f1769a99-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769c2a-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769cbb-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769bbf-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='b16a3747-d1b5-4bae-8c33-19b4ad9aa944'), NodeId(space='inference_space', external_id='f1769c85-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769b59-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769b43-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769d1a-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd90156-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='a4bc44aa-25e4-684a-ab2c-c7fc3378d9e5'), NodeId(space='inference_space', external_id='2dd901a2-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd9040c-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769b21-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769b5d-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769c8a-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference ...
#  UploadResult(name='Edges', error_messages=[], issues=[], created=set(), upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set()),
#  UploadResult(name='Nodes', error_messages=[], issues=[], created={NodeId(space='inference_space', external_id='f1769ec7-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f17698f1-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f176985a-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769e7d-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769eee-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769f20-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='80fbd5bc-44ef-a449-bd3a-a332871d687c'), NodeId(space='inference_space', external_id='f1769ed9-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769ede-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769f18-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd902f1-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769ec1-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd901d0-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='d7ee793b-dc47-1446-9589-6b9f71a74045'), NodeId(space='inference_space', external_id='2dd9035c-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd9029c-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769f1c-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f176980a-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='ef44b349-9aa5-cf4d-9252-d3c7f7d4a58f'), NodeId(space='inference_space', external_id='f1769b90-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd90425-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd90203-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd90485-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769ee9-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769f2c-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769efd-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='91bb6456-f9da-f844-834a-ee713c43d32e'), NodeId(space='inference_space', external_id='f1769e8a-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f176995d-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd901e5-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f17698e6-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd90230-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769ec6-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769ec3-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769f19-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769839-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd902f5-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='4439bb91-7c9b-1b41-a091-8ae3600d3349'), NodeId(space='inference_space', external_id='f17699fa-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd902f8-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769e89-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd90259-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd9030b-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769ea6-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769ee0-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f176981c-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference ...
#  UploadResult(name='Edges', error_messages=[], issues=[], created=set(), upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set()),
#  UploadResult(name='Nodes', error_messages=[], issues=[], created={NodeId(space='inference_space', external_id='f17696e0-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2f1e5d68-8cdf-42f6-9e73-2cb91da1c91a'), NodeId(space='inference_space', external_id='2dd9023a-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd9022e-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769dfa-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd90456-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='0b8fd844-ca69-4cc9-82b5-3225991235b6'), NodeId(space='inference_space', external_id='f1769664-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd901b0-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='e34b8faa-ede0-4000-8c7d-d8df46a37416'), NodeId(space='inference_space', external_id='425e8921-3fb6-4b08-99f4-bdbef61e9620'), NodeId(space='inference_space', external_id='9098d05f-45b6-7b4f-b176-a6995b423baa'), NodeId(space='inference_space', external_id='f17695b8-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f17699c0-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd901b6-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f17697a6-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769b6c-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='a93b83d7-8a39-ef48-8c29-36de1ac0eaf5'), NodeId(space='inference_space', external_id='83f55d5f-90cd-da41-82ac-86783a45ab16'), NodeId(space='inference_space', external_id='2dd901bd-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769caa-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd9018d-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769d8e-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='c356ea84-abae-cb43-895f-7118f2f82b3e'), NodeId(space='inference_space', external_id='1e396889-dffa-414e-a6f0-c79dfe612d8f'), NodeId(space='inference_space', external_id='2dd90163-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd901a1-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f17697fa-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='709001cd-13d9-4d1e-9a4e-553cd24f0724'), NodeId(space='inference_space', external_id='cf91c2cb-551a-e14c-8295-85c979c5c75e'), NodeId(space='inference_space', external_id='2dd90167-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='29aa9783-38df-407a-99dd-bf19ddba7fef'), NodeId(space='inference_space', external_id='f1769722-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='07a43fc4-0dca-554d-9d57-b1b721912b5a'), NodeId(space='inference_space', external_id='f17696b8-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='urn:uuid:2dd9014f-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f1769aac-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769740-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769d04-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='d8739dc3-ffab-4457-b819-a20579c4d0fc'), NodeId(space='inference_space', external_id='6527036e-b9b9-684b-a1fe-1e94910e3771'), NodeId(space='inference_space', external_id='2dd90172-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='2dd903f9-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space='inference_space', external_id='f17697b2-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='f1769da0-9aeb-11e5-91da-b8763fd99c5f'), NodeId(space='inference_space', external_id='2dd9047b-bdfb-11e5-94fa-c8f73332c8f4'), NodeId(space=' ...
#  UploadResult(name='Edges', error_messages=[], issues=[], created=set(), upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set())]

# %% [markdown]
# Results of the upload should be visible in the CDF project such as in the following screenshot:
#
# <img src="../../artifacts/figs/data-model-nordic44.png" width="800">
#
# <img src="../../artifacts/figs/instances-nordic44.png" width="800">
